# %% [markdown]
# # Eric González Caballero - MSc Big Data Analytics Thesis
# ## Forecasting the System Imbalance in the Spanish Electricity Market
#
#
# ### Notebook 01 - DataIngestion
#
# This notebook aims to ingest the data from the REE ESIOS API for the desired indicators and the desired dates
#
# Official API documentation can be found at: https://api.esios.ree.es/
#
# A useful library for easing ingestions via the ESIOS API is used, developed by Santiago Peñate Vera (santiago.penate.vera@gmail.com) under the GNU General Public License and available at https://github.com/SanPen/ESIOS which was slightly modified to adapt it to the needs of this project.

# %% [markdown]
# #### Libraries import

# %%
# Import general libraries
import requests
import json

import numpy as np
import pandas as pd

import datetime
import holidays

import sys
sys.path.append('../libraries')

# Import modified esios library
from utils_esios_mod import *

# %% [markdown]
# #### Constants definition
# Set the different needed dates, mainly the initial and final ingestion dates that can depend on the current day. For a full load, data from 2019 (a lot of indicators were added then) onwards is ingested, maximum date is the next day at 23h, when some forecast indicators are already available.

# %%
# Define constans
# Dynamic dates, time in UTC+01/02 (Spanish local time, not utc)
now = datetime.datetime.now()
today = datetime.date.today()

yesterday = today - datetime.timedelta(days=1)
tomorrow = today + datetime.timedelta(days=1)

# Format the timestamp to be included in the name
tmstmp = str(now.strftime("%Y_%m_%d"))

# Set desired dates to be used in the correct format
start = "2019-01-01T00:00:00"
end = tomorrow.strftime("%Y-%m-%dT23:00:00")

# I/O paths
raw_path = '../data/raw/data_' + tmstmp + '.csv'
curated_path = '../data/curated/data_bronze.csv'

# ESIOS personal token
token = '0c74832e546dfc1ba873175f25fcdf1773b4b0ee37f6d5d767d5e3791f129a47' #Personal token, should be in a private config file or key vault

# %% [markdown]
# #### Query Data
# Instantiate the ESIOS custom class with the personal token and query the list of available indicators

# %%
esios = ESIOS(token)
# Out:
# Getting the indicators...

# %%
resp = requests.get('https://api.esios.ree.es/indicators',
                  headers={'Authorization': 'Token token="%s"' % (token)})

print(f"There are {len(resp.json()['indicators'])} indicators available:")

for element in resp.json()['indicators']: print(str(element['id']) + ': ' + element['name'])
# Out:
# There are 1878 indicators available:
# 1901: Precio medio horario componente RD-L 10/2022 mercado diario e intradiario - diferencia por liquidación con medidas
# 10405: Precio medio horario componente mecanismo de ajuste RD-L 10/2022 comercializadores de referencia
# 10404: Precio medio horario componente mecanismo de ajuste RD-L 10/2022 contratación libre
# 10403: Precio medio horario componente mecanismo de ajuste RD-L 10/2022
# 1909: Precio medio horario componente RD-L 10/2022 mercado diario e intradiario comercializadores de referencia
# 1908: Precio medio horario componente RD-L 10/2022 mercado diario e intradiario contratación libre
# 1907: Precio medio horario componente RD-L 10/2022 mercado diario e intradiario
# 1906: Precio medio horario componente RD-L 10/2022 restricciones técnicas y mercados de balance comercializadores de referencia
# 1905: Mecanismo de ajuste contratacion libre
# 1904: Precio medio horario componente RD-L 10/2022 restricciones técnicas y mercados de balance contratación libre
# 1903: Precio medio horario componente RD-L 10/2022 mercado diario e intradiario - diferencia por liquidación con medidas comercializadores de referencia
# 1902: Precio medio horario componenSte RD-L 10/2022 mercado diario e intradiario - diferencia por liquidación con medidas contratación libre
# 1900: Desglose peaje por defecto 2.0TD excedente o déficit de la liquidación del mecanismo de ajuste de costes de producción
# 10395: Asignación regulación terciaria subir
# 10401: Precio medio ponderado regulación terciaria a bajar de activación directa (AD)
# 10400: Precio medio ponderado regulación terciaria a subir de activación directa (AD)
# 10399: Precio medio ponderado regulación terciaria a bajar de activación programada (AP)
# 10398: Precio medio ponderado regulación terciaria a subir de activación programada (AP)
# 10396: Energía regulación terciaria a subir de activación directa (AD)
# 10397: Energía regulación terciaria a bajar de activación directa (AD)
# 10394: Asignación regulación terciaria bajar
# 1898: Obligaciones de pago del proceso de regulación terciaria activación directa
# 1894: Necesidad regulación terciaria a subir de activación directa (AD)
# 1896: Derechos de cobro del proceso de regulación terciaria activación directa
# 1897: Obligaciones de pago del proceso de regulación terciaria activación programada
# 1895: Derechos de cobro del proceso de regulación terciaria activación programada
# 1883: Energía regulación terciaria a bajar asignada en QH0 de activación directa (AD QH0)
# 1893: Necesidad regulación terciaria a bajar de activación directa (AD)
# 1892: Necesidad regulación terciaria a subir de activación programada (AP)
# 1891: Necesidad regulación terciaria a bajar de activación programada (AP)
# 1886: Energía regulación terciaria a subir asignada en QH1 de activación directa (AD QH1)
# 1885: Energía regulación terciaria a bajar asignada en QH1 de activación directa (AD QH1)
# 1884: Energía regulación terciaria a subir asignada en QH0 de activación directa (AD QH0)
# 10393: Desglose peaje 2.0TD Término de energía
# 10391: Término de facturación de energía activa del PVPC 2.0TD suma componentes
# 1879: Desglose peaje por defecto 2.0TD Excedente o déficit subastas renovables
# 1878: Desglose peaje por defecto 2.0TD Coste de comercialización
# 1001: Término de facturación de energía activa del PVPC 2.0TD
# 1877: Desglose peaje por defecto 2.0TD Financiación OS
# 1876: Desglose peaje por defecto 2.0TD Peajes y cargos
# 1875: Desglose peaje por defecto 2.0TD Mercado diario e intradiario
# 1874: Desglose peaje por defecto 2.0TD Financiación OM
# 1873: Desglose peaje por defecto 2.0TD Servicio de interrumpibilidad
# 1872: Desglose peaje por defecto 2.0TD Pago por capacidad
# 1871: Desglose peaje por defecto 2.0TD Servicios de ajuste
# 1006: Perfiles de consumo a efectos de facturación del PVPC Tarifa 2.0TD
# 1005: Término de facturación de energía activa del PVPC 2.0TD P3 valle
# 1004: Término de facturación de energía activa del PVPC 2.0TD P2 llano
# 1003: Término de facturación de energía activa del PVPC 2.0TD P1 punta
# 1002: Periodo Tarifario del PVPC 2.0TD
# 10392: Precio medio ponderado programación de reserva adicional Tiempo Real
# 1881: Reserva adicional programada en Tiempo Real
# 1880: Necesidades de reserva adicional identificadas en Tiempo Real
# 10304: Potencia instalada de generación total libre de emisiones
# 1490: Potencia instalada de generación residuos no renovables
# 1489: Potencia instalada de generación cogeneración
# 1488: Potencia instalada de generación otras renovables
# 1487: Potencia instalada de generación solar térmica
# 1486: Potencia instalada de generación solar fotovoltaica
# 10303: Potencia instalada de generación total con emisiones
# 10301: Potencia instalada de generación total no renovable
# 10300: Potencia instalada de generación total
# 1485: Potencia instalada de generación eólica
# 1484: Potencia instalada de generación hidroeólica
# 1483: Potencia instalada de generación ciclo combinado
# 10302: Potencia instalada de generación total renovable
# 1491: Potencia instalada de generación residuos renovables
# 1478: Potencia instalada de generación carbón
# 1482: Potencia instalada de generación fuel+gas
# 1481: Potencia instalada de generación turbina de vapor
# 1480: Potencia instalada de generación turbina de gas
# 1475: Potencia instalada de generación hidraúlica
# 1477: Potencia instalada de generación nuclear
# 1476: Potencia instalada de turbinación de bombeo
# 1479: Potencia instalada de generación motores diesel
# 10390: Precio medio ponderado de regulación secundaria a bajar
# 10389: Precio medio ponderado de regulación secundaria a subir
# 10388: Precio medio ponderado banda de regulación secundaria
# 10387: Precio medio ponderado regulación terciaria a bajar
# 10386: Precio medio ponderado regulación terciaria a subir
# 10385: Precio medio ponderado de las necesidades cubiertas de energías de balance RR a bajar
# 10384: Precio medio ponderado de las necesidades cubiertas de energías de balance RR a subir
# 10383: Necesidad total solicitada de energías de balance RR
# 1870: Necesidad elástica solicitada de energías de balance RR
# 1844: Capacidad de intercambio comercial prevista en la interconexión con Francia horizonte diario importación
# 1850: Capacidad de intercambio comercial prevista en la interconexión con Marruecos horizonte diario exportación
# 1849: Capacidad de intercambio comercial prevista en la interconexión con Portugal horizonte diario exportación
# 1848: Capacidad de intercambio comercial prevista en la interconexión con Francia horizonte diario exportación
# 1846: Capacidad de intercambio comercial prevista en la interconexión con Marruecos horizonte diario importación
# 1845: Capacidad de intercambio comercial prevista en la interconexión con Portugal horizonte diario importación
# 1840: Energía de exportación intercambiada entre IGCC y SEPE
# 1839: Energía de importación intercambiada entre IGCC y SEPE
# 1843: Beneficio estimado para SEPE del proceso de compensación de desequilibrio
# 1841: Precio final de liquidación del proceso de compensación de desequilibrio
# 1829: Requisito mínimo de control de flujo en España-Francia en sentido exportador
# 1831: Requisito mínimo de control de flujo en España-Francia en sentido importador
# 1834: Renta de congestión energías de balance RR Portugal importación
# 1838: Asignación a bajar de energías de balance RR por IC SEE
# 1837: Asignación a subir de energías de balance RR por IC SEE
# 1836: Renta de congestión energías de balance RR Francia importación
# 1835: Renta de congestión energías de balance RR Francia exportación
# 1833: Renta de congestión energías de balance RR Portugal exportación
# 1832: Liquidación del SEE por requisitos de control de flujo
# 1830: Requisito máximo de control de flujo en España-Francia en sentido importador
# 1824: Requisito máximo de control de flujo en España-Portugal en sentido exportador
# 1827: Requisito mínimo de control de flujo en España-Portugal en sentido importador
# 1828: Requisito máximo de control de flujo en España-Francia en sentido exportador
# 1826: Requisito máximo de control de flujo en España-Portugal en sentido importador
# 1825: Requisito mínimo de control de flujo en España-Portugal en sentido exportador
# 1820: Generación T.Real enlace Ibiza-Formentera SNP
# 1822: Generación T.Real enlace Mallorca-Ibiza SNP
# 1821: Generación T.Real enlace Mallorca-Menorca SNP
# 10369: Energía asignada por restricciones técnicas en tiempo real Absoluto SCA
# 10376: Energía asignada por restricciones técnicas en tiempo real Absoluto ASE
# 10375: Energía asignada por restricciones técnicas en tiempo real Absoluto RBI
# 10374: Energía asignada por restricciones técnicas en tiempo real Absoluto RSI
# 10373: Energía asignada por restricciones técnicas en tiempo real Absoluto Otros
# 10372: Energía asignada por restricciones técnicas en tiempo real Absoluto EST
# 10371: Energía asignada por restricciones técnicas en tiempo real Absoluto RTD
# 10370: Energía asignada por restricciones técnicas en tiempo real Absoluto CT
# 10367: Energía asignada por restricciones técnicas diario Fase I Absoluto Otros
# 10366: Energía asignada por restricciones técnicas diario Fase I Absoluto EST
# 10365: Energía asignada por restricciones técnicas diario Fase I Absoluto RTD
# 10364: Energía asignada por restricciones técnicas diario Fase I Absoluto CT
# 10363: Energía asignada por restricciones técnicas diario Fase I Absoluto SCA
# 10362: Energía asignada por restricciones técnicas diario Fase I Absoluto SCB
# 10368: Energía asignada por restricciones técnicas en tiempo real Absoluto SCB
# 1817: Energía asignada por restricciones técnicas en tiempo real Bajar RBI
# 1816: Energía asignada por restricciones técnicas en tiempo real Subir RBI
# 1815: Energía asignada por restricciones técnicas en tiempo real Bajar RSI
# 1805: Energía asignada por restricciones técnicas en tiempo real Bajar SCA
# 1804: Energía asignada por restricciones técnicas en tiempo real Subir SCA
# 1803: Energía asignada por restricciones técnicas en tiempo real Bajar SCB
# 1802: Energía asignada por restricciones técnicas en tiempo real Subir SCB
# 1801: Energía asignada por restricciones técnicas diario Fase I Bajar Otros
# 1800: Energía asignada por restricciones técnicas diario Fase I Subir Otros
# 1799: Energía asignada por restricciones técnicas diario Fase I Bajar EST
# 1798: Energía asignada por restricciones técnicas diario Fase I Subir EST
# 1814: Energía asignada por restricciones técnicas en tiempo real Subir RSI
# 1813: Energía asignada por restricciones técnicas en tiempo real Bajar Otros
# 1812: Energía asignada por restricciones técnicas en tiempo real Subir Otros
# 1811: Energía asignada por restricciones técnicas en tiempo real Bajar EST
# 1810: Energía asignada por restricciones técnicas en tiempo real Subir EST
# 1809: Energía asignada por restricciones técnicas en tiempo real Bajar RTD
# 1808: Energía asignada por restricciones técnicas en tiempo real Subir RTD
# 1807: Energía asignada por restricciones técnicas en tiempo real Bajar CT
# 1806: Energía asignada por restricciones técnicas en tiempo real Subir CT
# 1819: Energía asignada por restricciones técnicas en tiempo real Bajar ASE
# 1818: Energía asignada por restricciones técnicas en tiempo real Subir ASE
# 1790: Energía asignada por restricciones técnicas diario Fase I Subir SCB
# 1797: Energía asignada por restricciones técnicas diario Fase I Bajar RTD
# 1796: Energía asignada por restricciones técnicas diario Fase I Subir RTD
# 1795: Energía asignada por restricciones técnicas diario Fase I Bajar CT
# 1794: Energía asignada por restricciones técnicas diario Fase I Subir CT
# 1793: Energía asignada por restricciones técnicas diario Fase I Bajar SCA
# 1792: Energía asignada por restricciones técnicas diario Fase I Subir SCA
# 1791: Energía asignada por restricciones técnicas diario Fase I Bajar SCB
# 10382: Precio medio horario componente servicios de balance y otros contratación libre
# 10381: Precio medio horario componente servicios de balance y otros comercializadores de referencia
# 10380: Precio medio horario componente servicios de balance y otros
# 10379: Precio medio horario componente restricciones técnicas contratación libre
# 10378: Precio medio horario componente restricciones técnicas comercializadores de referencia
# 10377: Precio medio horario componente restricciones técnicas
# 1789: Requerimientos de terciaria bajar
# 1788: Requerimientos de terciaria subir
# 1398: Solicitud de aplicación del servicio interrumpilidad por criterios técnicos
# 1399: Solicitud de aplicación del servicio interrumpilidad a efectos de comprobación del funcionamiento efectivo del servicio
# 10361: Programas balance transfronterizo exportación
# 10360: Programas balance transfronterizo importación
# 1782: Precio energías de balance RR
# 1787: Necesidad inelástica solicitada de energías de balance RR
# 1784: Asignación a bajar de energías de balance RR SEE
# 1783: Asignación a subir de energías de balance RR SEE
# 10359: Previsión intradiaria H+3 eólica más fotovoltaica
# 10358: Previsión diaria D+1 eólica más fotovoltaica
# 1780: Previsión intradiaria H+3 fotovoltaica
# 1779: Previsión diaria D+1 fotovoltaica
# 1778: Previsión intradiaria H+3 eólica
# 1777: Previsión diaria D+1 eólica
# 1776: Previsión intradiaria H+3 demanda
# 1775: Previsión diaria D+1 demanda
# 1774: Previsión demanda anual
# 1756: Generación medida Térmica renovable
# 10062: Generación medida Residuos renovables
# 1757: Generación medida Térmica no renovable
# 10356: CO2 Asociado Generación T.Real SNP
# 10355: CO2 Asociado Generación T.Real
# 10354: Generación T.Real no renovable SNP
# 10353: Generación T.Real renovable SNP
# 10352: Generación T.Real no renovable
# 10351: Generación T.Real renovable
# 10350: Demanda real suma de generación SNP
# 1748: Generación T.Real solar fotovoltaica SNP
# 1749: Generación T.Real hidráulica SNP
# 1747: Generación T.Real turbina de vapor SNP
# 1755: Generación T.Real cogeneración SNP
# 1754: Generación T.Real generación auxiliar SNP
# 1753: Generación T.Real residuos SNP
# 1752: Generación T.Real otras renovables SNP
# 1745: Generación T.Real eólica SNP
# 1741: Demanda programada SNP
# 1751: Generación T.Real enlace balear SNP
# 1746: Generación T.Real ciclo combinado SNP
# 1744: Generación T.Real turbina de gas SNP
# 1743: Generación T.Real motores diésel SNP
# 1750: Generación T.Real carbón SNP
# 1740: Demanda Real SNP
# 1742: Demanda prevista SNP
# 1739: Precio de la energía excedentaria del autoconsumo para el mecanismo de compensación simplificada (PVPC)
# 899: Coste asignación de banda de Regulación Secundaria
# 1727: Precio de referencia en Mercado Intradiario Continuo
# 1723: Coste del proceso de solución de Restricciones Técnicas de Seguridad en Tiempo Real a Subir
# 10341: Precio medio ponderado de solución de Restricciones Técnicas de Seguridad en Tiempo Real bajar
# 10340: Precio medio ponderado de solución de Restricciones Técnicas de Seguridad en Tiempo Real subir
# 1726: Energía limitada con derechos de cobro por restricciones en tiempo real a bajar
# 1725: Energía limitada con derechos de cobro por restricciones en tiempo real a subir
# 1724: Coste del proceso de solución de Restricciones Técnicas de Seguridad en Tiempo Real a Bajar
# 10329: Precio medio anual componente servicios ajuste del sistema
# 10328: Precio medio mensual componente servicios ajuste del sistema
# 10327: Precio medio ponderado restricciones técnicas diario bajar
# 10326: Precio medio ponderado restricciones técnicas diario subir
# 10325: Energía total asignada por seguridad y de balance
# 10324: Energía de balance a bajar
# 10323: Energía de balance a subir
# 10322: Energía asignada por seguridad a bajar
# 10321: Energía asignada por seguridad a subir
# 1690: Demanda en Mallorca - Menorca - Ibiza - Formentera
# 1691: Generación en Mallorca - Menorca - Ibiza - Formentera
# 1674: Capacidad Reducida Largo Plazo Francia sentido importador
# 1683: Capacidad Largo Plazo No Nominada Francia sentido exportador
# 1682: Capacidad Largo Plazo No Nominada Francia sentido importador
# 1677: Capacidad Reducida Largo Plazo Portugal sentido exportador
# 1676: Capacidad Reducida Largo Plazo Portugal sentido importador
# 1675: Capacidad Reducida Largo Plazo Francia sentido exportador
# 1680: Compensaciones por reducciones de capacidad Portugal-España importación
# 1687: Remuneración Capacidad Largo plazo Portugal-España exportación
# 1686: Remuneración Capacidad Largo plazo Portugal-España importación
# 1685: Remuneración Capacidad Largo plazo Francia-España exportación
# 1684: Remuneración Capacidad Largo plazo Francia-España importación
# 1681: Compensaciones por reducciones de capacidad Portugal-España exportación
# 1678: Compensaciones por reducciones de capacidad Francia-España importación
# 1679: Compensaciones por reducciones de capacidad Francia-España exportación
# 1662: Rentas de congestión subastas explícitas mensual Portugal importación
# 1667: Rentas de congestión subastas explícitas anual Portugal exportación
# 1666: Rentas de congestión subastas explícitas anual Portugal importación
# 1665: Rentas de congestión subastas explícitas trimestral Portugal exportación
# 1664: Rentas de congestión subastas explícitas trimestral Portugal importación
# 1663: Rentas de congestión subastas explícitas mensual Portugal exportación
# 1644: Precio de subasta explícita mensual de capacidad en la interconexión con Portugal sentido importador
# 1661: Precio de subasta explícita anual de capacidad en la interconexión con Portugal sentido exportador
# 1660: Precio de subasta explícita anual de capacidad en la interconexión con Portugal sentido importador
# 1653: Precio de subasta explícita trimestral de capacidad en la interconexión con Portugal sentido exportador
# 1652: Precio de subasta explícita trimestral de capacidad en la interconexión con Portugal sentido importador
# 1645: Precio de subasta explícita mensual de capacidad en la interconexión con Portugal sentido exportador
# 1640: Participantes adjudicatarios en subasta explícita mensual de capacidad en la interconexión con Portugal sentido importador
# 1657: Participantes adjudicatarios en subasta explícita anual de capacidad en la interconexión con Portugal sentido exportador
# 1656: Participantes adjudicatarios en subasta explícita anual de capacidad en la interconexión con Portugal sentido importador
# 1649: Participantes adjudicatarios en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido exportador
# 1648: Participantes adjudicatarios en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido importador
# 1641: Participantes adjudicatarios en subasta explícita mensual de capacidad en la interconexión con Portugal sentido exportador
# 1642: Capacidad asignada en subasta explícita mensual de capacidad en la interconexión con Portugal sentido importador
# 1659: Capacidad asignada en subasta explícita anual de capacidad en la interconexión con Portugal sentido exportador
# 1658: Capacidad asignada en subasta explícita anual de capacidad en la interconexión con Portugal sentido importador
# 1651: Capacidad asignada en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido exportador
# 1650: Capacidad asignada en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido importador
# 1643: Capacidad asignada en subasta explícita mensual de capacidad en la interconexión con Portugal sentido exportador
# 1638: Participantes en subasta explícita mensual de capacidad en la interconexión con Portugal sentido importador
# 1655: Participantes en subasta explícita anual de capacidad en la interconexión con Portugal sentido exportador
# 1654: Participantes en subasta explícita anual de capacidad en la interconexión con Portugal sentido importador
# 1647: Participantes en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido exportador
# 1646: Participantes en subasta explícita trimestral de capacidad en la interconexión con Portugal sentido importador
# 1639: Participantes en subasta explícita mensual de capacidad en la interconexión con Portugal sentido exportador
# 1632: Capacidad ofrecida subasta explícita mensual de capacidad en la interconexión con Portugal sentido importador
# 1637: Capacidad ofrecida subasta explícita anual de capacidad en la interconexión con Portugal sentido exportador
# 1636: Capacidad ofrecida subasta explícita anual de capacidad en la interconexión con Portugal sentido importador
# 1635: Capacidad ofrecida subasta explícita trimestral de capacidad en la interconexión con Portugal sentido exportador
# 1634: Capacidad ofrecida subasta explícita trimestral de capacidad en la interconexión con Portugal sentido importador
# 1633: Capacidad ofrecida subasta explícita mensual de capacidad en la interconexión con Portugal sentido exportador
# 10238: Generación programada P48 Exportación Total
# 10237: Generación programada P48 Importación Total
# 1442: Energía asignada en Mercado Intradiario Continuo
# 10271: Generación programada PHFC UGH + no UGH
# 10287: Generación programada PHFC total
# 10286: Generación programada + Consumo bombeo + Cable Baleares PHFC
# 10285: Ajuste de programas PHFC
# 10284: Saldo total interconexiones programa PHFC
# 10283: Generación programada PHFC otras renovables
# 10282: Generación programada PHFC Carbón
# 10281: Generación programada PHFC Eólica
# 10280: Generación programada PHFC Anexo II RD 134/2010
# 10279: Demanda programada PHFC total
# 10278: Generación programada PHFC Saldo Andorra
# 10277: Generación programada PHFC Saldo Marruecos
# 10273: Generación programada PHFC Cogeneración
# 10276: Generación programada PHFC Saldo Portugal
# 10275: Generación programada PHFC Saldo Francia
# 10274: Generación programada PHFC Residuos
# 10272: Generación programada PHFC Fuel-Gas
# 1430: Generación programada PHFC Importación Andorra
# 1429: Generación programada PHFC Importación Marruecos
# 1428: Generación programada PHFC Importación Portugal
# 1427: Generación programada PHFC Importación Francia
# 1426: Generación programada PHFC Genéricas
# 1425: Generación programada PHFC Enlace Baleares
# 1424: Generación programada PHFC Consumo bombeo
# 1423: Generación programada PHFC Residuos varios
# 1439: Demanda programada PHFC Corrección eólica
# 1437: Demanda programada PHFC Consumos directos en mercado
# 1438: Demanda programada PHFC Consumo de Servicios Auxiliares
# 1441: Demanda programada PHFC Corrección REE
# 1436: Demanda programada PHFC Comercializadores de referencia
# 1440: Demanda programada PHFC Corrección solar
# 1435: Demanda programada PHFC Comercializadores mercado libre
# 1434: Generación programada PHFC Exportación Andorra
# 1433: Generación programada PHFC Exportación Marruecos
# 1432: Generación programada PHFC Exportación Portugal
# 1431: Generación programada PHFC Exportación Francia
# 1409: Generación programada PHFC Fuel
# 1408: Generación programada PHFC Ciclo combinado
# 1407: Generación programada PHFC Hulla sub-bituminosa
# 1406: Generación programada PHFC Hulla antracita
# 1405: Generación programada PHFC Hulla sub-bituminosa Anexo II RD 134/2010
# 1404: Generación programada PHFC Hulla antracita Anexo II RD 134/2010
# 1403: Generación programada PHFC Nuclear
# 1402: Generación programada PHFC Turbinación bombeo
# 1401: Generación programada PHFC Hidráulica no UGH
# 1400: Generación programada PHFC Hidráulica UGH
# 1422: Generación programada PHFC Residuos domésticos y similares
# 1421: Generación programada PHFC Biogás
# 1420: Generación programada PHFC Biomasa
# 1419: Generación programada PHFC Energía residual
# 1418: Generación programada PHFC Subproductos minería
# 1417: Generación programada PHFC Derivados del petróleo ó carbón
# 1416: Generación programada PHFC Gas Natural Cogeneración
# 1415: Generación programada PHFC Océano y geotérmica
# 1414: Generación programada PHFC Solar térmica
# 1413: Generación programada PHFC Solar fotovoltaica
# 1412: Generación programada PHFC Eólica marina
# 1411: Generación programada PHFC Eólica terrestre
# 1410: Generación programada PHFC Gas Natural
# 10270: Energía asignada restricciones técnicas diario Fase II
# 1397: Solicitud de aplicación del servicio interrumpilidad por criterios económicos
# 1396: Nº de Clientes > 450 kW nivel de tensión EB >= 30 kV y < 36 kV
# 1395: Nº de Clientes > 450 kW nivel de tensión EA >= 1 kV y < 30 kV
# 1394: Demanda medida nivel de tensión EB >= 30 kV y < 36 kV
# 1393: Demanda medida nivel de tensión EA >= 1 kV y < 30 kV
# 1391: Precio de derechos de emisión de despacho de los TNP (PCO2D)
# 1390: Desglose vehículo eléctrico 2.0.DHS Coste de comercialización
# 1389: Desglose eficiencia 2 periodos (DHA) 2.0.DHA Coste de comercialización
# 1388: Desglose peaje por defecto 2.0.A Coste de comercialización
# 1380: Balance de desvíos medidos cierre de energía subir
# 1387: Balance de desvíos medidos desvío UP genérica bajar
# 1386: Balance de desvíos medidos desvío UP genérica subir
# 1385: Balance de desvíos medidos enlace balear bajar
# 1384: Balance de desvíos medidos enlace balear subir
# 1383: Balance de desvíos medidos interrumpibilidad bajar
# 1382: Balance de desvíos medidos interrumpibilidad subir
# 1381: Balance de desvíos medidos cierre de energía bajar
# 1379: Balance de desvíos medidos servicios transfronterizos de balance bajar
# 1378: Balance de desvíos medidos servicios transfronterizos de balance subir
# 1000: Cierre liquidación
# 10269: Demanda medida nivel de tensión total
# 10268: Demanda medida tarifa de acceso total
# 10267: Demanda medida discriminación horaria total
# 10266: Generación programada PHF7 total
# 10265: Generación programada PHF6 total
# 10264: Generación programada PHF5 total
# 10263: Generación programada PHF4 total
# 10262: Generación programada PHF3 total
# 10261: Generación programada PHF2 total
# 10260: Generación programada PHF1 total
# 10259: Generación programada PVP total
# 10258: Generación programada PBF total
# 10257: Generación programada P48 total
# 1373: Coste de solución de restricciones técnicas diario Fase I subir
# 1376: Coste de solución de restricciones técnicas diario Fase II bajar
# 1375: Coste de solución de restricciones técnicas diario Fase II subir
# 1374: Coste de solución de restricciones técnicas diario Fase I bajar
# 1370: Demanda medida tarifa de acceso 6.1B >= 30 KV Y < 36 KV
# 1372: Nº de Clientes > 450 kW tarifa de acceso 6.1B >= 30 KV Y < 36 KV
# 1371: Nº de Clientes > 450 kW tarifa de acceso 6.1A >= 1 KV Y < 30 KV
# 1369: Demanda medida tarifa de acceso 6.1A >= 1 KV Y < 30 KV
# 10256: Desglose vehículo eléctrico 2.0.DHS Término de energía
# 10255: Desglose eficiencia 2 periodos (DHA) 2.0.DHA Término de energía
# 10254: Desglose peaje por defecto 2.0.A Término de energía
# 1368: Precio medio horario componente incumplimiento energía de balance
# 1367: Precio medio horario componente incumplimiento energía de balance comercialización de referencia
# 1366: Precio medio horario componente incumplimiento energía de balance contratación libre
# 1365: Precio medio anual componente incumplimiento energía de balance
# 1364: Precio medio anual componente incumplimiento energía de balance comercialización de referencia
# 1363: Precio medio anual componente incumplimiento energía de balance contratación libre
# 1362: Precio medio mensual componente incumplimiento energía de balance
# 1361: Precio medio mensual componente incumplimiento energía de balance comercialización de referencia
# 1360: Precio medio mensual componente incumplimiento energía de balance contratación libre
# 10253: Volumen neto de Energía asignada por restricciones en tiempo real
# 10252: Volumen neto de energía utilizada de regulación secundaria
# 10251: Volumen neto de necesidades cubiertas de energías de balance RR
# 10250: Volumen neto de asignación regulación terciaria
# 10249: Previsión de la demanda residual
# 10244: Demanda en Baleares
# 10248: Generación en los SNP
# 10246: Generación en Canarias
# 10245: Demanda en los SNP
# 10243: Demanda en Canarias
# 10247: Generación en Baleares
# 1358: Generación en Melilla
# 1339: Demanda en Gran Canaria
# 1355: Generación en Mallorca - Menorca
# 1354: Generación en El Hierro
# 1352: Generación en La Palma
# 1356: Generación en Ibiza - Formentera
# 1350: Generación en Lanzarote y Fuerteventura
# 1347: Demanda en Ceuta
# 1346: Demanda en Ibiza - Formentera
# 1345: Demanda en Mallorca - Menorca
# 1344: Demanda en El Hierro
# 1343: Demanda en La Gomera
# 1357: Generación en Ceuta
# 1351: Generación en Tenerife
# 1349: Generación en Gran Canaria
# 1348: Demanda en Melilla
# 1353: Generación en La Gomera
# 1342: Demanda en La Palma
# 1341: Demanda en Tenerife
# 1340: Demanda en Lanzarote y Fuerteventura
# 1338: Volumen neto de los desvíos generación-demanda
# 1337: Precio medio de la generación en los SNP por subsistema
# 1336: Precio medio de la demanda en los SNP por subsistema
# 1335: Demanda del sistema a efectos del cálculo de perfiles
# 10242: Capacidad de intercambio disponible tras la programación en la interconexión con Francia exportación
# 10241: Capacidad de intercambio disponible tras la programación en la interconexión con Francia importación
# 10236: Programa bilateral PBF Total Compras
# 10235: Programa bilateral PBF Total Ventas
# 10234: Programa bilateral PBF Otras renovables
# 10233: Programa bilateral PBF Carbón
# 10232: Potencia disponible de generación total horizonte año móvil
# 10231: Término de facturación de energía activa del PVPC vehículo eléctrico suma componentes
# 10230: Término de facturación de energía activa del PVPC eficiencia 2 periodos (DHA) suma componentes
# 10229: Término de facturación de energía activa del PVPC peaje por defecto suma componentes
# 10228: Generación programada + Consumo bombeo + Cable Baleares PVP
# 10227: Generación programada + Consumo bombeo + Cable Baleares PHF7
# 10226: Generación programada + Consumo bombeo + Cable Baleares PHF6
# 10225: Generación programada + Consumo bombeo + Cable Baleares PHF5
# 10224: Generación programada + Consumo bombeo + Cable Baleares PHF4
# 10223: Generación programada + Consumo bombeo + Cable Baleares PHF3
# 10222: Generación programada + Consumo bombeo + Cable Baleares PHF2
# 10221: Generación programada + Consumo bombeo + Cable Baleares PHF1
# 10220: Generación programada + Consumo bombeo + Cable Baleares PBF
# 10219: Precio medio mensual final contratación libre suma de componentes
# 10218: Precio medio mensual final comercialización de referencia suma de componentes
# 10216: Precio medio mensual final suma de componentes
# 10217: Precio medio anual final suma de componentes
# 10215: Precio medio anual final comercialización de referencia suma de componentes
# 10214: Precio medio horario final contratación libre suma de componentes
# 10213: Precio medio anual final contratación libre suma de componentes
# 10212: Precio medio horario final comercializadores de referencia suma de componentes
# 10211: Precio medio horario final suma de componentes
# 10210: Saldo horario neto de interconexión con Andorra telemedidas
# 10209: Saldo horario neto de interconexión con Marruecos telemedidas
# 10208: Saldo horario neto de interconexión con Portugal telemedidas
# 10207: Saldo horario neto de interconexión con Francia telemedidas
# 10206: Generación T.Real Solar
# 1334: Energía asignada en Mercado SPOT Diario Francia
# 1333: Precio mínimo de ofertas de balance presentadas por Portugal para exportación activadas por el SEE
# 1319: Precio máximo de ofertas de balance presentadas por Portugal para exportación activadas por el SEE
# 1317: Precio máximo de ofertas de balance presentadas por Francia para exportación activadas por el SEE
# 1316: Precio máximo de ofertas de balance presentadas por Francia para importación activadas por el SEE
# 1332: Precio mínimo de ofertas de balance presentadas por Portugal para importación activadas por el SEE
# 1330: Precio mínimo de ofertas de balance presentadas por Francia para importación activadas por el SEE
# 1329: Precio mínimo de ofertas de balance presentadas por SEE para exportación activadas por Portugal
# 1327: Precio mínimo de ofertas de balance presentadas por SEE para exportación activadas por Francia
# 1326: Precio mínimo de ofertas de balance presentadas por SEE para importación activadas por Francia
# 1324: Precio mínimo de ofertas de balance presentadas por Portugal para importación
# 1321: Precio mínimo de ofertas de balance presentadas por SEE para exportación
# 1331: Precio mínimo de ofertas de balance presentadas por Francia para exportación activadas por el SEE
# 1328: Precio mínimo de ofertas de balance presentadas por SEE para importación activadas por Portugal
# 1325: Precio mínimo de ofertas de balance presentadas por Portugal para exportación
# 1322: Precio mínimo de ofertas de balance presentadas por Francia para importación
# 1320: Precio mínimo de ofertas de balance presentadas por SEE para importación
# 1318: Precio máximo de ofertas de balance presentadas por Portugal para importación activadas por el SEE
# 1315: Precio máximo de ofertas de balance presentadas por SEE para exportación activadas por Portugal
# 1323: Precio mínimo de ofertas de balance presentadas por Francia para exportación
# 1302: Precio medio de ofertas de balance presentadas por Francia para importación
# 1313: Precio máximo de ofertas de balance presentadas por SEE para exportación activadas por Francia
# 1311: Precio máximo de ofertas de balance presentadas por Portugal para exportación
# 1310: Precio máximo de ofertas de balance presentadas por Portugal para importación
# 1308: Precio máximo de ofertas de balance presentadas por Francia para importación
# 1307: Precio máximo de ofertas de balance presentadas por SEE para exportación
# 1305: Precio medio de ofertas de balance presentadas por Portugal para exportación
# 1303: Precio medio de ofertas de balance presentadas por Francia para exportación
# 1312: Precio máximo de ofertas de balance presentadas por SEE para importación activadas por Francia
# 1309: Precio máximo de ofertas de balance presentadas por Francia para exportación
# 1306: Precio máximo de ofertas de balance presentadas por SEE para importación
# 1304: Precio medio de ofertas de balance presentadas por Portugal para importación
# 1301: Energía de ofertas de balance presentadas por Portugal para exportación
# 1299: Energía de ofertas de balance presentadas por Francia para exportación
# 1298: Energía de ofertas de balance presentadas por Francia para importación
# 1300: Energía de ofertas de balance presentadas por Portugal para importación
# 1314: Precio máximo de ofertas de balance presentadas por SEE para importación activadas por Portugal
# 1297: Generación T.Real Cogeneración y resto
# 1296: Generación T.Real Térmica renovable
# 1295: Generación T.Real Solar fotovoltaica
# 1294: Generación T.Real Solar térmica
# 10205: Generación medida solar
# 10204: Ajuste de programas PHF7
# 10203: Ajuste de programas PHF6
# 10202: Ajuste de programas PHF5
# 10201: Ajuste de programas PHF4
# 10200: Ajuste de programas PHF3
# 10199: Ajuste de programas PHF2
# 10198: Ajuste de programas PHF1
# 10197: Ajuste de programas PVP
# 10196: Ajuste de programas PBF
# 10195: Generación medida total tipo producción
# 1293: Demanda real
# 10194: Saldo total interconexiones programa PHF7
# 10193: Saldo total interconexiones programa PHF6
# 10192: Saldo total interconexiones programa PHF5
# 10191: Saldo total interconexiones programa PHF4
# 10190: Saldo total interconexiones programa PHF3
# 10189: Saldo total interconexiones programa PHF2
# 10188: Saldo total interconexiones programa PHF1
# 10187: Saldo total interconexiones programa PVP
# 10186: Saldo total interconexiones programa PBF
# 1292: Precio medio anual componente control factor potencia
# 1291: Precio medio anual componente control factor potencia comercializadores de referencia
# 1290: Precio medio anual componente control factor potencia contratación libre
# 1289: Precio medio mensual componente control factor potencia
# 1288: Precio medio mensual componente control factor potencia comercializador de referencia
# 1287: Precio medio mensual componente control factor potencia contratación libre
# 1286: Precio medio horario componente control factor potencia
# 1285: Precio medio horario componente control factor potencia contratación libre
# 1284: Precio medio horario componente control factor potencia comercializadores de referencia
# 1283: Precio medio anual componente servicio de interrumpibilidad
# 1282: Precio medio anual componente servicio de interrumpibilidad comercializadores de referencia
# 1281: Precio medio anual componente servicio de interrumpibilidad contratación libre
# 1280: Precio medio mensual componente servicio de interrumpibilidad
# 1279: Precio medio mensual componente servicio de interrumpibilidad comercializadores de referencia
# 1278: Precio medio mensual componente servicio de interrumpibilidad contratación libre
# 1277: Precio medio horario componente servicio de interrumpibilidad
# 1276: Precio medio horario componente servicio de interrumpibilidad contratación libre
# 1275: Precio medio horario componente servicio de interrumpibilidad comercializadores de referencia
# 10183: Generación programada PHF7 otras renovables
# 10182: Generación programada PHF6 otras renovables
# 10181: Generación programada PHF5 otras renovables
# 10180: Generación programada PHF4 otras renovables
# 10179: Generación programada PHF3 otras renovables
# 10178: Generación programada PHF2 otras renovables
# 10177: Generación programada PHF1 otras renovables
# 10176: Generación programada PVP otras renovables
# 10175: Generación programada PHF7 Carbón
# 10174: Generación programada PHF6 Carbón
# 10173: Generación programada PHF5 Carbón
# 10172: Generación programada PHF4 Carbón
# 10171: Generación programada PHF3 Carbón
# 10170: Generación programada PHF2 Carbón
# 10169: Generación programada PHF1 Carbón
# 10168: Generación programada PVP Carbón
# 10167: Generación programada PBF Carbón
# 10165: Generación programada PHF7 Eólica
# 10164: Generación programada PHF6 Eólica
# 10163: Generación programada PHF5 Eólica
# 10162: Generación programada PHF4 Eólica
# 10161: Generación programada PHF3 Eólica
# 10160: Generación programada PHF2 Eólica
# 10159: Generación programada PHF1 Eólica
# 10158: Generación programada PVP Eólica
# 10157: Generación programada PHF7 Anexo II RD 134/2010
# 10156: Generación programada PHF6 Anexo II RD 134/2010
# 10155: Generación programada PHF5 Anexo II RD 134/2010
# 10154: Generación programada PHF4 Anexo II RD 134/2010
# 10153: Generación programada PHF3 Anexo II RD 134/2010
# 10152: Generación programada PHF2 Anexo II RD 134/2010
# 10151: Generación programada PHF1 Anexo II RD 134/2010
# 10150: Generación programada PVP Anexo II RD 134/2010
# 10149: Demanda programada PHF7 total
# 10148: Demanda programada PHF6 total
# 10147: Demanda programada PHF5 total
# 10146: Demanda programada PHF4 total
# 10145: Demanda programada PHF3 total
# 10144: Demanda programada PHF2 total
# 10143: Demanda programada PHF1 total
# 10142: Demanda programada PVP total
# 10141: Demanda programada PBF total
# 10140: Generación programada PHF7 Saldo Andorra
# 10139: Generación programada PHF6 Saldo Andorra
# 10138: Generación programada PHF5 Saldo Andorra
# 10137: Generación programada PHF4 Saldo Andorra
# 10136: Generación programada PHF3 Saldo Andorra
# 10134: Generación programada PHF2 Saldo Andorra
# 10133: Generación programada PHF1 Saldo Andorra
# 10132: Generación programada PVP Saldo Andorra
# 10131: Generación programada PBF Saldo Andorra
# 10130: Generación programada PHF7 Saldo Marruecos
# 10129: Generación programada PHF6 Saldo Marruecos
# 10128: Generación programada PHF5 Saldo Marruecos
# 10127: Generación programada PHF4 Saldo Marruecos
# 10126: Generación programada PHF3 Saldo Marruecos
# 10125: Generación programada PHF2 Saldo Marruecos
# 10124: Generación programada PHF1 Saldo Marruecos
# 10123: Generación programada PVP Saldo Marruecos
# 10122: Generación programada PBF Saldo Marruecos
# 10121: Generación programada PHF7 Saldo Portugal
# 10120: Generación programada PHF6 Saldo Portugal
# 10119: Generación programada PHF5 Saldo Portugal
# 10118: Generación programada PHF4 Saldo Portugal
# 10117: Generación programada PHF3 Saldo Portugal
# 10116: Generación programada PHF2 Saldo Portugal
# 10115: Generación programada PHF1 Saldo Portugal
# 10114: Generación programada PVP Saldo Portugal
# 10113: Generación programada PBF Saldo Portugal
# 10112: Generación programada PHF7 Saldo Francia
# 10111: Generación programada PHF6 Saldo Francia
# 10110: Generación programada PHF5 Saldo Francia
# 10109: Generación programada PHF4 Saldo Francia
# 10108: Generación programada PHF3 Saldo Francia
# 10107: Generación programada PHF2 Saldo Francia
# 10106: Generación programada PHF1 Saldo Francia
# 10105: Generación programada PVP Saldo Francia
# 10104: Generación programada PBF Saldo Francia
# 10103: Generación programada PHF7 Residuos
# 10102: Generación programada PHF6 Residuos
# 10101: Generación programada PHF5 Residuos
# 10100: Generación programada PHF4 Residuos
# 10099: Generación programada PHF3 Residuos
# 10098: Generación programada PHF2 Residuos
# 10097: Generación programada PHF1 Residuos
# 10096: Generación programada PVP Residuos
# 10095: Generación programada PBF Residuos
# 10094: Generación programada PHF7 Cogeneración
# 10093: Generación programada PHF6 Cogeneración
# 10092: Generación programada PHF5 Cogeneración
# 10091: Generación programada PHF4 Cogeneración
# 10090: Generación programada PHF3 Cogeneración
# 10089: Generación programada PHF2 Cogeneración
# 10088: Generación programada PHF1 Cogeneración
# 10087: Generación programada PVP Cogeneración
# 10086: Generación programada PBF Cogeneración
# 10085: Generación programada PHF7 Fuel-Gas
# 10084: Generación programada PHF6 Fuel-Gas
# 10083: Generación programada PHF5 Fuel-Gas
# 10082: Generación programada PHF4 Fuel-Gas
# 10081: Generación programada PHF3 Fuel-Gas
# 10080: Generación programada PHF2 Fuel-Gas
# 10079: Generación programada PHF1 Fuel-Gas
# 10078: Generación programada PVP Fuel-Gas
# 10077: Generación programada PBF Fuel-Gas
# 10075: Generación programada PBF Anexo II RD 134/2010
# 10074: Generación programada PBF otras renovables
# 10073: Generación programada PBF Eólica
# 10072: Generación programada PHF7 UGH + no UGH
# 10071: Generación programada PHF6 UGH + no UGH
# 10070: Generación programada PHF5 UGH + no UGH
# 10069: Generación programada PHF4 UGH + no UGH
# 10068: Generación programada PHF3 UGH + no UGH
# 10067: Generación programada PHF2 UGH + no UGH
# 10066: Generación programada PHF1 UGH + no UGH
# 10065: Generación programada PVP UGH + no UGH
# 10064: Generación programada PBF UGH + no UGH
# 10063: Generación programada P48 UGH + no UGH
# 10061: Generación programada P48 Anexo II RD 134/2010
# 10059: Demanda proveedores del servicio de interrumpibilidad Sectores
# 855: Potencia residual de referencia agregada Vidrio
# 898: Potencia residual de referencia
# 896: Potencia residual de referencia agregada Cemento
# 854: Potencia residual de referencia agregada Maquinaria
# 853: Potencia residual de referencia agregada Química
# 851: Potencia residual de referencia agregada Desalación
# 850: Potencia residual de referencia agregada Papel
# 897: Potencia residual de referencia agregada Varios
# 852: Potencia residual de referencia agregada Metalurgia
# 835: CO2 evitable
# 848: Potencia residual de referencia agregada Madera
# 846: Demanda proveedores del servicio de interrumpibilidad Varios
# 845: Demanda proveedores del servicio de interrumpibilidad Cemento
# 842: Demanda proveedores del servicio de interrumpibilidad Maquinaria
# 839: Demanda proveedores del servicio de interrumpibilidad Desalación
# 837: Demanda proveedores del servicio de interrumpibilidad Siderurgia
# 836: Demanda proveedores del servicio de interrumpibilidad Madera
# 849: Potencia residual de referencia agregada Siderurgia
# 847: Demanda proveedores del servicio de interrumpibilidad
# 844: Demanda proveedores del servicio de interrumpibilidad Vidrio
# 840: Demanda proveedores del servicio de interrumpibilidad Metalurgia
# 838: Demanda proveedores del servicio de interrumpibilidad Papel
# 834: CO2 evitable Varios
# 841: Demanda proveedores del servicio de interrumpibilidad Química
# 824: CO2 evitable Madera
# 833: CO2 evitable Cemento
# 828: CO2 evitable Metalurgia
# 827: CO2 evitable Desalación
# 832: CO2 evitable Vidrio
# 829: CO2 evitable Química
# 826: CO2 evitable Papel
# 831: CO2 evitable Maquinaria
# 825: CO2 evitable Siderurgia
# 819: Energía mensual final comercializadores de referencia cuota
# 823: Energía anual final cuota
# 821: Energía anual final comercialización libre cuota
# 820: Energía mensual final cuota
# 818: Energía mensual final contratación libre cuota
# 822: Energía anual final comercializadores de referencia cuota
# 10058: Demanda en consumo diferencia generación - pérdidas
# 1274: Nº de Clientes > 450 kW tarifa de acceso T.3 TRACCIÓN MAYOR DE 72.5 KV
# 1273: Nº de Clientes > 450 kW tarifa de acceso T.2 TRACCIÓN MAYOR DE 36 KV Y NO SUPERIOR A 72.5 KV
# 1272: Nº de Clientes > 450 kW tarifa de acceso T.1 TRACCIÓN NO SUPERIOR A 36 KV
# 1270: Nº de Clientes > 450 kW tarifa de acceso G.6 GENERAL ALTA TENSIÓN CONEXIONES INTERNACIONALES
# 1268: Nº de Clientes > 450 kW tarifa de acceso G.4 GENERAL ALTA TENSIÓN >= 72.5 KV Y < 145 KV
# 1271: Nº de Clientes > 450 kW tarifa de acceso R.0 GENERAL BAJA TENSIÓN RIEGOS AGRÍCOLAS
# 1269: Nº de Clientes > 450 kW tarifa de acceso G.5 GENERAL ALTA TENSIÓN > 145 KV
# 1255: Nº de Clientes > 450 kW tarifa de acceso 6.1 >= 1 KV Y < 36 KV
# 1267: Nº de Clientes > 450 kW tarifa de acceso G.3 GENERAL ALTA TENSIÓN >= 36 KV Y < 72.5 KV
# 1266: Nº de Clientes > 450 kW tarifa de acceso G.2 GENERAL ALTA TENSIÓN >= 14 KV Y < 36 KV
# 1265: Nº de Clientes > 450 kW tarifa de acceso G.1 GENERAL ALTA TENSIÓN >= 1 KV Y < 14 KV
# 1264: Nº de Clientes > 450 kW tarifa de acceso D.4 DISTRIBUIDORES DE MAS DE 145 KV
# 1262: Nº de Clientes > 450 kW tarifa de acceso D.2 DISTRIBUIDORES MAYOR DE 36 KV Y NO SUPERIOR A 72.5 KV
# 1261: Nº de Clientes > 450 kW tarifa de acceso D.1 DISTRIBUIDORES NO SUPERIORES 36 KV
# 1260: Nº de Clientes > 450 kW tarifa de acceso B.0 GENERAL BAJA TENSIÓN ALUMBRADO PÚBLICO
# 1259: Nº de Clientes > 450 kW tarifa de acceso 6.5 CONEXIONES INTERNACIONALES
# 1258: Nº de Clientes > 450 kW tarifa de acceso 6.4 >= 145 KV
# 1257: Nº de Clientes > 450 kW tarifa de acceso 6.3 >= 72.5 KV Y < 145 KV
# 1256: Nº de Clientes > 450 kW tarifa de acceso 6.2 >= 30 KV Y < 72.5 KV
# 1254: Nº de Clientes > 450 kW tarifa de acceso 4.0 GENERAL BAJA TENSIÓN LARGA UTILIZACIÓN
# 1253: Nº de Clientes > 450 kW tarifa de acceso 3.1A DE 1 A 36 KV DE TRES PERIODOS
# 1252: Nº de Clientes > 450 kW tarifa de acceso 3.0A GENERAL BAJA TENSIÓN
# 1263: Nº de Clientes > 450 kW tarifa de acceso D.3 DISTRIBUIDORES MAYOR DE 72.5 KV Y NO SUPERIOR A 145 KV
# 1245: Nº de Clientes > 450 kW nivel de tensión E4 >= 72.5 kV y < 145 kV
# 1246: Nº de Clientes > 450 kW nivel de tensión E5 >= 145 kV y < 220 kV
# 1244: Nº de Clientes > 450 kW nivel de tensión E3 >= 36 kV y < 72.5 kV
# 1239: Nº de Clientes > 450 kW discriminación horaria E4 TARIFA DE TRES PERIODOS CON DISCRIMINACIÓN HORARIA DE TIPO 4
# 1238: Nº de Clientes > 450 kW discriminación horaria E3 TARIFA DE TRES PERIODOS
# 1237: Nº de Clientes > 450 kW discriminación horaria E2 TARIFA DE DOS PERIODOS
# 1235: Nº de Clientes > 450 kW discriminación horaria G0 GENERAL ALTA TENSIÓN
# 1249: Nº de Clientes > 450 kW tarifa de acceso 2.0 GENERAL BAJA TENSIÓN, POTENCIA NO SUPERIOR A 15 KW
# 1251: Nº de Clientes > 450 kW tarifa de acceso 2.0 GENERAL BAJA TENSIÓN, POTENCIA NO SUPERIOR A 10 KW
# 1248: Nº de Clientes > 450 kW tarifa de acceso Sin tarifa de acceso
# 1243: Nº de Clientes > 450 kW nivel de tensión E2 >= 14 kV y < 36 kV
# 1241: Nº de Clientes > 450 kW nivel de tensión E0 Baja tensión
# 1240: Nº de Clientes > 450 kW nivel de tensión Sin nivel tensión
# 1236: Nº de Clientes > 450 kW discriminación horaria E1 TARIFA DE UN PERIODO
# 1247: Nº de Clientes > 450 kW nivel de tensión E6 >= 220 kV
# 1242: Nº de Clientes > 450 kW nivel de tensión E1 >= 1 kV y < 14 kV
# 1250: Nº de Clientes > 450 kW tarifa de acceso 2.1 GENERAL BAJA TENSIÓN, POTENCIA SUPERIOR A 10 KW Y NO SUPERIOR A 15 KW
# 1184: Nº Puntos Frontera Distribución - Distribución
# 1191: Nº de Clientes > 450 kW discriminación horaria Sin discriminación horaria
# 1189: Nº Puntos Frontera Generación RO - Transporte
# 1187: Nº Puntos Frontera Generación RE - Distribución
# 1186: Nº Puntos Frontera Generación RE - Transporte
# 1190: Nº Puntos Frontera Transporte - Internacional
# 1188: Nº Puntos Frontera Generación RO - Distribución
# 1185: Nº Puntos Frontera Distribución - Transporte
# 10057: Energía total mercado de producción
# 10056: Volumen absoluto de Energía utilizada de Regulación Secundaria
# 10055: Volumen absoluto de asignación Regulación Terciaria
# ...
# 317: Generación programada PHF7 Hidráulica no UGH
# 318: Generación programada PHF7 Turbinación bombeo
# 316: Generación programada PHF7 Hidráulica UGH
# 319: Generación programada PHF7 Nuclear
# 315: Generación programada PHF6 Exportación Andorra
# 314: Generación programada PHF6 Exportación Marruecos
# 313: Generación programada PHF6 Exportación Portugal
# 309: Generación programada PHF6 Importación Portugal
# 308: Generación programada PHF6 Importación Francia
# 312: Generación programada PHF6 Exportación Francia
# 311: Generación programada PHF6 Importación Andorra
# 310: Generación programada PHF6 Importación Marruecos
# 307: Generación programada PHF6 Genéricas
# 305: Generación programada PHF6 Consumo bombeo
# 303: Generación programada PHF6 Residuos domésticos y similares
# 302: Generación programada PHF6 Biogás
# 306: Generación programada PHF6 Enlace Baleares
# 304: Generación programada PHF6 Residuos varios
# 297: Generación programada PHF6 Gas Natural Cogeneración
# 300: Generación programada PHF6 Energía residual
# 298: Generación programada PHF6 Derivados del petróleo ó carbón
# 295: Generación programada PHF6 Solar térmica
# 296: Generación programada PHF6 Océano y geotérmica
# 301: Generación programada PHF6 Biomasa
# 299: Generación programada PHF6 Subproductos minería
# 289: Generación programada PHF6 Ciclo combinado
# 293: Generación programada PHF6 Eólica marina
# 292: Generación programada PHF6 Eólica terrestre
# 290: Generación programada PHF6 Fuel
# 294: Generación programada PHF6 Solar fotovoltaica
# 291: Generación programada PHF6 Gas Natural
# 287: Generación programada PHF6 Hulla antracita
# 288: Generación programada PHF6 Hulla sub-bituminosa
# 285: Generación programada PHF6 Hulla antracita Anexo II RD 134/2010
# 284: Generación programada PHF6 Nuclear
# 286: Generación programada PHF6 Hulla sub-bituminosa Anexo II RD 134/2010
# 283: Generación programada PHF6 Turbinación bombeo
# 276: Generación programada PHF5 Importación Andorra
# 282: Generación programada PHF6 Hidráulica no UGH
# 280: Generación programada PHF5 Exportación Andorra
# 279: Generación programada PHF5 Exportación Marruecos
# 277: Generación programada PHF5 Exportación Francia
# 281: Generación programada PHF6 Hidráulica UGH
# 278: Generación programada PHF5 Exportación Portugal
# 270: Generación programada PHF5 Consumo bombeo
# 271: Generación programada PHF5 Enlace Baleares
# 275: Generación programada PHF5 Importación Marruecos
# 274: Generación programada PHF5 Importación Portugal
# 272: Generación programada PHF5 Genéricas
# 273: Generación programada PHF5 Importación Francia
# 264: Generación programada PHF5 Subproductos minería
# 268: Generación programada PHF5 Residuos domésticos y similares
# 267: Generación programada PHF5 Biogás
# 265: Generación programada PHF5 Energía residual
# 269: Generación programada PHF5 Residuos varios
# 266: Generación programada PHF5 Biomasa
# 261: Generación programada PHF5 Océano y geotérmica
# 263: Generación programada PHF5 Derivados del petróleo ó carbón
# 262: Generación programada PHF5 Gas Natural Cogeneración
# 260: Generación programada PHF5 Solar térmica
# 259: Generación programada PHF5 Solar fotovoltaica
# 258: Generación programada PHF5 Eólica marina
# 254: Generación programada PHF5 Ciclo combinado
# 257: Generación programada PHF5 Eólica terrestre
# 255: Generación programada PHF5 Fuel
# 253: Generación programada PHF5 Hulla sub-bituminosa
# 252: Generación programada PHF5 Hulla antracita
# 256: Generación programada PHF5 Gas Natural
# 246: Generación programada PHF5 Hidráulica UGH
# 250: Generación programada PHF5 Hulla antracita Anexo II RD 134/2010
# 249: Generación programada PHF5 Nuclear
# 247: Generación programada PHF5 Hidráulica no UGH
# 251: Generación programada PHF5 Hulla sub-bituminosa Anexo II RD 134/2010
# 248: Generación programada PHF5 Turbinación bombeo
# 242: Generación programada PHF4 Exportación Francia
# 245: Generación programada PHF4 Exportación Andorra
# 244: Generación programada PHF4 Exportación Marruecos
# 240: Generación programada PHF4 Importación Marruecos
# 243: Generación programada PHF4 Exportación Portugal
# 241: Generación programada PHF4 Importación Andorra
# 236: Generación programada PHF4 Enlace Baleares
# 237: Generación programada PHF4 Genéricas
# 235: Generación programada PHF4 Consumo bombeo
# 239: Generación programada PHF4 Importación Portugal
# 238: Generación programada PHF4 Importación Francia
# 231: Generación programada PHF4 Biomasa
# 233: Generación programada PHF4 Residuos domésticos y similares
# 232: Generación programada PHF4 Biogás
# 230: Generación programada PHF4 Energía residual
# 234: Generación programada PHF4 Residuos varios
# 224: Generación programada PHF4 Solar fotovoltaica
# 228: Generación programada PHF4 Derivados del petróleo ó carbón
# 227: Generación programada PHF4 Gas Natural Cogeneración
# 225: Generación programada PHF4 Solar térmica
# 226: Generación programada PHF4 Océano y geotérmica
# 229: Generación programada PHF4 Subproductos minería
# 220: Generación programada PHF4 Fuel
# 223: Generación programada PHF4 Eólica marina
# 221: Generación programada PHF4 Gas Natural
# 218: Generación programada PHF4 Hulla sub-bituminosa
# 219: Generación programada PHF4 Ciclo combinado
# 222: Generación programada PHF4 Eólica terrestre
# 212: Generación programada PHF4 Hidráulica no UGH
# 216: Generación programada PHF4 Hulla sub-bituminosa Anexo II RD 134/2010
# 215: Generación programada PHF4 Hulla antracita Anexo II RD 134/2010
# 213: Generación programada PHF4 Turbinación bombeo
# 217: Generación programada PHF4 Hulla antracita
# 214: Generación programada PHF4 Nuclear
# 210: Generación programada PHF3 Exportación Andorra
# 208: Generación programada PHF3 Exportación Portugal
# 206: Generación programada PHF3 Importación Andorra
# 211: Generación programada PHF4 Hidráulica UGH
# 209: Generación programada PHF3 Exportación Marruecos
# 207: Generación programada PHF3 Exportación Francia
# 202: Generación programada PHF3 Genéricas
# 205: Generación programada PHF3 Importación Marruecos
# 203: Generación programada PHF3 Importación Francia
# 201: Generación programada PHF3 Enlace Baleares
# 200: Generación programada PHF3 Consumo bombeo
# 204: Generación programada PHF3 Importación Portugal
# 196: Generación programada PHF3 Biomasa
# 198: Generación programada PHF3 Residuos domésticos y similares
# 197: Generación programada PHF3 Biogás
# 195: Generación programada PHF3 Energía residual
# 199: Generación programada PHF3 Residuos varios
# 189: Generación programada PHF3 Solar fotovoltaica
# 193: Generación programada PHF3 Derivados del petróleo ó carbón
# 192: Generación programada PHF3 Gas Natural Cogeneración
# 190: Generación programada PHF3 Solar térmica
# 194: Generación programada PHF3 Subproductos minería
# 191: Generación programada PHF3 Océano y geotérmica
# 185: Generación programada PHF3 Fuel
# 188: Generación programada PHF3 Eólica marina
# 187: Generación programada PHF3 Eólica terrestre
# 184: Generación programada PHF3 Ciclo combinado
# 186: Generación programada PHF3 Gas Natural
# 183: Generación programada PHF3 Hulla sub-bituminosa
# 177: Generación programada PHF3 Hidráulica no UGH
# 181: Generación programada PHF3 Hulla sub-bituminosa Anexo II RD 134/2010
# 178: Generación programada PHF3 Turbinación bombeo
# 180: Generación programada PHF3 Hulla antracita Anexo II RD 134/2010
# 182: Generación programada PHF3 Hulla antracita
# 179: Generación programada PHF3 Nuclear
# 172: Generación programada PHF2 Exportación Francia
# 176: Generación programada PHF3 Hidráulica UGH
# 175: Generación programada PHF2 Exportación Andorra
# 173: Generación programada PHF2 Exportación Portugal
# 174: Generación programada PHF2 Exportación Marruecos
# 167: Generación programada PHF2 Genéricas
# 171: Generación programada PHF2 Importación Andorra
# 170: Generación programada PHF2 Importación Marruecos
# 168: Generación programada PHF2 Importación Francia
# 169: Generación programada PHF2 Importación Portugal
# 162: Generación programada PHF2 Biogás
# 166: Generación programada PHF2 Enlace Baleares
# 163: Generación programada PHF2 Residuos domésticos y similares
# 161: Generación programada PHF2 Biomasa
# 165: Generación programada PHF2 Consumo bombeo
# 164: Generación programada PHF2 Residuos varios
# 160: Generación programada PHF2 Energía residual
# 159: Generación programada PHF2 Subproductos minería
# 155: Generación programada PHF2 Solar térmica
# 158: Generación programada PHF2 Derivados del petróleo ó carbón
# 157: Generación programada PHF2 Gas Natural Cogeneración
# 156: Generación programada PHF2 Océano y geotérmica
# 149: Generación programada PHF2 Ciclo combinado
# 153: Generación programada PHF2 Eólica marina
# 152: Generación programada PHF2 Eólica terrestre
# 150: Generación programada PHF2 Fuel
# 151: Generación programada PHF2 Gas Natural
# 154: Generación programada PHF2 Solar fotovoltaica
# 143: Generación programada PHF2 Turbinación bombeo
# 148: Generación programada PHF2 Hulla sub-bituminosa
# 147: Generación programada PHF2 Hulla antracita
# 145: Generación programada PHF2 Hulla antracita Anexo II RD 134/2010
# 144: Generación programada PHF2 Nuclear
# 146: Generación programada PHF2 Hulla sub-bituminosa Anexo II RD 134/2010
# 138: Generación programada PHF1 Exportación Portugal
# 142: Generación programada PHF2 Hidráulica no UGH
# 140: Generación programada PHF1 Exportación Andorra
# 139: Generación programada PHF1 Exportación Marruecos
# 137: Generación programada PHF1 Exportación Francia
# 141: Generación programada PHF2 Hidráulica UGH
# 134: Generación programada PHF1 Importación Portugal
# 132: Generación programada PHF1 Genéricas
# 135: Generación programada PHF1 Importación Marruecos
# 136: Generación programada PHF1 Importación Andorra
# 133: Generación programada PHF1 Importación Francia
# 131: Generación programada PHF1 Enlace Baleares
# 126: Generación programada PHF1 Biomasa
# 130: Generación programada PHF1 Consumo bombeo
# 128: Generación programada PHF1 Residuos domésticos y similares
# 127: Generación programada PHF1 Biogás
# 129: Generación programada PHF1 Residuos varios
# 121: Generación programada PHF1 Océano y geotérmica
# 125: Generación programada PHF1 Energía residual
# 123: Generación programada PHF1 Derivados del petróleo ó carbón
# 122: Generación programada PHF1 Gas Natural Cogeneración
# 120: Generación programada PHF1 Solar térmica
# 124: Generación programada PHF1 Subproductos minería
# 118: Generación programada PHF1 Eólica marina
# 117: Generación programada PHF1 Eólica terrestre
# 115: Generación programada PHF1 Fuel
# 119: Generación programada PHF1 Solar fotovoltaica
# 116: Generación programada PHF1 Gas Natural
# 112: Generación programada PHF1 Hulla antracita
# 110: Generación programada PHF1 Hulla antracita Anexo II RD 134/2010
# 114: Generación programada PHF1 Ciclo combinado
# 111: Generación programada PHF1 Hulla sub-bituminosa Anexo II RD 134/2010
# 109: Generación programada PHF1 Nuclear
# 113: Generación programada PHF1 Hulla sub-bituminosa
# 103: Generación programada P48 Exportación Portugal
# 106: Generación programada PHF1 Hidráulica UGH
# 104: Generación programada P48 Exportación Marruecos
# 107: Generación programada PHF1 Hidráulica no UGH
# 108: Generación programada PHF1 Turbinación bombeo
# 105: Generación programada P48 Exportación Andorra
# 99: Generación programada P48 Importación Portugal
# 101: Generación programada P48 Importación Andorra
# 100: Generación programada P48 Importación Marruecos
# 98: Generación programada P48 Importación Francia
# 102: Generación programada P48 Exportación Francia
# 96: Generación programada P48 Enlace Baleares
# 97: Generación programada P48 Genéricas
# 93: Generación programada P48 Residuos domésticos y similares
# 92: Generación programada P48 Biogás
# 94: Generación programada P48 Residuos varios
# 95: Generación programada P48 Consumo bombeo
# 86: Generación programada P48 Océano y geotérmica
# 90: Generación programada P48 Energía residual
# 88: Generación programada P48 Derivados del petróleo ó carbón
# 87: Generación programada P48 Gas Natural Cogeneración
# 91: Generación programada P48 Biomasa
# 89: Generación programada P48 Subproductos minería
# 85: Generación programada P48 Solar térmica
# 83: Generación programada P48 Eólica marina
# 82: Generación programada P48 Eólica terrestre
# 80: Generación programada P48 Fuel
# 84: Generación programada P48 Solar fotovoltaica
# 81: Generación programada P48 Gas Natural
# 77: Generación programada P48 Hulla antracita
# 79: Generación programada P48 Ciclo combinado
# 76: Generación programada P48 Hulla sub-bituminosa Anexo II RD 134/2010
# 75: Generación programada P48 Hulla antracita Anexo II RD 134/2010
# 78: Generación programada P48 Hulla sub-bituminosa
# 70: Generación programada PVP Exportación Andorra
# 73: Generación programada P48 Turbinación bombeo
# 74: Generación programada P48 Nuclear
# 72: Generación programada P48 Hidráulica no UGH
# 71: Generación programada P48 Hidráulica UGH
# 69: Generación programada PVP Exportación Marruecos
# 66: Generación programada PVP Importación Andorra
# 65: Generación programada PVP Importación Marruecos
# 64: Generación programada PVP Importación Portugal
# 68: Generación programada PVP Exportación Portugal
# 67: Generación programada PVP Exportación Francia
# 61: Generación programada PVP Enlace Baleares
# 63: Generación programada PVP Importación Francia
# 60: Generación programada PVP Consumo bombeo
# 58: Generación programada PVP Residuos domésticos y similares
# 62: Generación programada PVP Genéricas
# 59: Generación programada PVP Residuos varios
# 54: Generación programada PVP Subproductos minería
# 57: Generación programada PVP Biogás
# 55: Generación programada PVP Energía residual
# 53: Generación programada PVP Derivados del petróleo ó carbón
# 56: Generación programada PVP Biomasa
# 49: Generación programada PVP Solar fotovoltaica
# 51: Generación programada PVP Océano y geotérmica
# 50: Generación programada PVP Solar térmica
# 48: Generación programada PVP Eólica marina
# 47: Generación programada PVP Eólica terrestre
# 52: Generación programada PVP Gas Natural Cogeneración
# 41: Generación programada PVP Hulla sub-bituminosa Anexo II RD 134/2010
# 45: Generación programada PVP Fuel
# 43: Generación programada PVP Hulla sub-bituminosa
# 42: Generación programada PVP Hulla antracita
# 46: Generación programada PVP Gas Natural
# 44: Generación programada PVP Ciclo combinado
# 36: Generación programada PVP Hidráulica UGH
# 39: Generación programada PVP Nuclear
# 35: Generación programada PBF Exportación Andorra
# 40: Generación programada PVP Hulla antracita Anexo II RD 134/2010
# 37: Generación programada PVP Hidráulica no UGH
# 38: Generación programada PVP Turbinación bombeo
# 31: Generación programada PBF Importación Andorra
# 34: Generación programada PBF Exportación Marruecos
# 32: Generación programada PBF Exportación Francia
# 30: Generación programada PBF Importación Marruecos
# 29: Generación programada PBF Importación Portugal
# 33: Generación programada PBF Exportación Portugal
# 24: Generación programada PBF Residuos varios
# 27: Generación programada PBF Genéricas
# 25: Generación programada PBF Consumo bombeo
# 23: Generación programada PBF Residuos domésticos y similares
# 28: Generación programada PBF Importación Francia
# 26: Generación programada PBF Enlace Baleares
# 17: Generación programada PBF Gas Natural Cogeneración
# 22: Generación programada PBF Biogás
# 21: Generación programada PBF Biomasa
# 19: Generación programada PBF Subproductos minería
# 20: Generación programada PBF Energía residual
# 18: Generación programada PBF Derivados del petróleo ó carbón
# 13: Generación programada PBF Eólica marina
# 16: Generación programada PBF Océano y geotérmica
# 14: Generación programada PBF Solar fotovoltaica
# 12: Generación programada PBF Eólica terrestre
# 15: Generación programada PBF Solar térmica
# 6: Generación programada PBF Hulla sub-bituminosa Anexo II RD 134/2010
# 11: Generación programada PBF Gas Natural
# 9: Generación programada PBF Ciclo combinado
# 7: Generación programada PBF Hulla antracita
# 10: Generación programada PBF Fuel
# 8: Generación programada PBF Hulla sub-bituminosa
# 2: Generación programada PBF Hidráulica no UGH
# 1: Generación programada PBF Hidráulica UGH
# 3: Generación programada PBF Turbinación bombeo
# 4: Generación programada PBF Nuclear
# 5: Generación programada PBF Hulla antracita Anexo II RD 134/2010

# %% [markdown]
# Query data from normal indicators (those that do not require special options like geographical aggregations)

# %%
# Read the normal variables by using the indicator id. Normal variables get update at 11h.
## 1775: Previsión diaria D+1 demanda
## 1293: Demanda real
## 545: Demanda programada
## 1779: Previsión diaria D+1 fotovoltaica
## 1777: Previsión diaria D+1 eólica
## 600: Precio mercado SPOT Diario

indicators = [1775, 1293, 545, 1779, 1777, 600]  ## Others 817, 544, 684, 1338, 1192, 10030, 10031, 10032, 767, 460, 10358]

# Query the data
df_list, names = esios.get_multiple_series(indicators, start, end)

# Merge the different series into a unique dataframe
df_merged = esios.merge_series(df_list, names)
# Out:
# Parsing Previsión diaria D+1 demanda
# Parsing Demanda real
# Parsing Demanda programada
# Parsing Previsión diaria D+1 fotovoltaica
# Parsing Previsión diaria D+1 eólica
# Parsing Precio mercado SPOT Diario
# merging

# %%
df = df_merged
df
# Out:
#                            Previsión diaria D+1 demanda  Demanda real  \
# datetime
# 2019-01-01 00:00:00+01:00                       23753.0       23676.0
# 2019-01-01 01:00:00+01:00                       23018.0       23128.0
# 2019-01-01 02:00:00+01:00                       21808.0       22109.0
# 2019-01-01 03:00:00+01:00                       20635.0       20666.0
# 2019-01-01 04:00:00+01:00                       19824.0       19680.0
# ...                                                 ...           ...
# 2022-08-10 19:00:00+02:00                       31688.3           NaN
# 2022-08-10 20:00:00+02:00                       31126.5           NaN
# 2022-08-10 21:00:00+02:00                       31363.5           NaN
# 2022-08-10 22:00:00+02:00                       30481.8           NaN
# 2022-08-10 23:00:00+02:00                       28347.0           NaN
#
#                            Demanda programada  \
# datetime
# 2019-01-01 00:00:00+01:00             23251.0
# 2019-01-01 01:00:00+01:00             22485.0
# 2019-01-01 02:00:00+01:00             20977.0
# 2019-01-01 03:00:00+01:00             19754.0
# 2019-01-01 04:00:00+01:00             19321.0
# ...                                       ...
# 2022-08-10 19:00:00+02:00                 NaN
# 2022-08-10 20:00:00+02:00                 NaN
# 2022-08-10 21:00:00+02:00                 NaN
# 2022-08-10 22:00:00+02:00                 NaN
# 2022-08-10 23:00:00+02:00                 NaN
#
#                            Previsión diaria D+1 fotovoltaica  \
# datetime
# 2019-01-01 00:00:00+01:00                                0.0
# 2019-01-01 01:00:00+01:00                                0.0
# 2019-01-01 02:00:00+01:00                                0.0
# 2019-01-01 03:00:00+01:00                                0.0
# 2019-01-01 04:00:00+01:00                                0.0
# ...                                                      ...
# 2022-08-10 19:00:00+02:00                             4284.4
# 2022-08-10 20:00:00+02:00                             1513.6
# 2022-08-10 21:00:00+02:00                               99.6
# 2022-08-10 22:00:00+02:00                                0.0
# 2022-08-10 23:00:00+02:00                                0.0
#
#                            Previsión diaria D+1 eólica  \
# datetime
# 2019-01-01 00:00:00+01:00                       3214.0
# 2019-01-01 01:00:00+01:00                       3222.0
# 2019-01-01 02:00:00+01:00                       3081.0
# 2019-01-01 03:00:00+01:00                       3069.0
# 2019-01-01 04:00:00+01:00                       2973.0
# ...                                                ...
# 2022-08-10 19:00:00+02:00                       4608.0
# 2022-08-10 20:00:00+02:00                       4780.5
# 2022-08-10 21:00:00+02:00                       5048.3
# 2022-08-10 22:00:00+02:00                       5336.0
# 2022-08-10 23:00:00+02:00                       5238.0
#
#                            Precio mercado SPOT Diario
# datetime
# 2019-01-01 00:00:00+01:00                       66.88
# 2019-01-01 01:00:00+01:00                       66.88
# 2019-01-01 02:00:00+01:00                       66.00
# 2019-01-01 03:00:00+01:00                       63.64
# 2019-01-01 04:00:00+01:00                       58.85
# ...                                               ...
# 2022-08-10 19:00:00+02:00                      153.15
# 2022-08-10 20:00:00+02:00                      166.50
# 2022-08-10 21:00:00+02:00                      171.68
# 2022-08-10 22:00:00+02:00                      170.01
# 2022-08-10 23:00:00+02:00                      163.95
#
# [31631 rows x 6 columns]

# %% [markdown]
# #### Output

# %%
# Save into raw with the timestamp in the name to keep the history
df.to_csv(raw_path, index=True)

# Save into curated as the latest file
df.to_csv(curated_path, index=True)

# %% [markdown]
# Query data from those indicators that require special options such as generation, which is presented by geo_codes (a lot of data, server collapses) and the national aggregated one is wished, therefore sum aggregation function is applied in the query, as they are uploaded into the ESIOS platform with a month of lag, they are not going to be used but code remains in case some other indicator is added in the future.

# %%
# indicators2 = [10043, 10037, 10205, 10035] ## Others 1153, 1156, 10039

# names2 = esios.get_names(indicators2)
# for name in names2: print(name)

# %%
# df_list = list()

# for id_code in indicators: #2:
#     df_new = esios_get(id_code, start_date, start_hour, end_date, end_hour, token, '&geo_agg=sum')
    
#     df_list.append(df_new)

# df2 = esios.merge_series(df_list, names2)   
# df2
